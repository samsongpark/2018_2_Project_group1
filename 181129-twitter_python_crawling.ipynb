# %%
# !pip install tweepy
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# grin 1.2.1 requires argparse>=1.1, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import tweepy

# 트위터 앱의 Keys and Access Tokens 탭 참조(자신의 설정 값을 넣어준다)
consumer_key = 'C2slqn36vbuFTNATEi0zSHFOM'
consumer_secret = 'O7W7ecCoJpIUUoEAxbtKYvP49pAv5AGgbi0ksDkpOJCeau39O8'

# 1. 인증요청(1차) : 개인 앱 정보 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

access_token = '1068019335879245825-ufSnakrsobPB0T9ltrabQk93Ck1wOu'
access_token_secret= 'wf0xqEGXF42AgdOQr9Ya64SYPGkpVG32nnOEWsznfOx4d'

# 2. access 토큰 요청(2차) - 인증요청 참조변수 이용
auth.set_access_token(access_token, access_token_secret)

# 3. twitter API 생성  
api = tweepy.API(auth)

keyword = "한진택배";     # 자신이 검색하고 싶은 키워드 입력 
search = [] # 크롤링 결과 저장할 변수   

cnt = 1
while(cnt <= 10):   # 10page 대상으로 크롤링
   tweets = api.search(keyword)
   for tweet in tweets:
       search.append(tweet)
   cnt += 1

print(len(search)) # 문서 길이 
print(search[0]) # 첫번째 text 보기
# Out:
# 150
# ...

# %%
#전체 문서 보기

data = {}   # 전체 문서 추가
i = 1       # 문서 번호
for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    print(i, " : ", data)   # 문서번호 : 문서내용
    i += 1
# Out:
# (1, ' : ', {'text': u'RT @parkjamjam_kr: \u2604\nNoted\nPieces\n\n\ud3ec\ud1a0\ubd81 \uc5b4\uc81c\ubd80\ud130 \uc21c\ucc28\uc801\uc73c\ub85c \ucd9c\uace0\uc911\uc785\ub2c8\ub2e4. \ube60\ub974\uba74 \uc624\ub298\ubd80\ud130 \ubc30\uc1a1\ubc1b\uc544 \ubcf4\uc2e4 \uc218 \uc788\uc5b4\uc694! \uc1a1\uc7a5\ubb38\uc758\ub294 \uae08\uc694\uc77c(23\uc77c)\ubd80\ud130 \ubc1b\uaca0\uc2b5\ub2c8\ub2e4.\n\ud0dd\ubc30\uc0ac\ub294 \ud55c\uc9c4\ud0dd\ubc30\uc785\ub2c8\ub2e4.\n\uad00\uc2ec\uac00\uc838\uc8fc\uc2dc\uace0 \ubbff\uace0 \uae30\ub2e4\ub824\uc8fc\uc2e0 \ubd84\ub4e4\u2026'})
# ...
